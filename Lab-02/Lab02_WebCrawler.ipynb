# %% [markdown]
# # Lab02: Web Crawler (Continue).
#
# - MSSV: 1712282
# - Họ và tên: LÊ ĐOÀN CÔNG ẢNH

# %% [markdown]
# ## Yêu cầu bài tập
#
# **Cách làm bài**
#
#
# Bạn sẽ làm trực tiếp trên file notebook này; trong file, từ `TODO` để cho biết những phần mà bạn cần phải làm.
#
# Bạn có thể thảo luận ý tưởng cũng như tham khảo các tài liệu, nhưng *code và bài làm phải là của bạn*.
#
# Nếu vi phạm thì sẽ bị 0 điểm cho bài tập này.
#
# **Cách nộp bài**
#
# Trước khi nộp bài, rerun lại notebook (`Kernel` -> `Restart & Run All`).
#
# Bạn nộp file notebook với tên `MSSV.ipynb` của bạn (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên file là `1234567.ipynb`) và nộp file này trên moodle.
#
# **Nội dung bài tập**
#
# Thu thập và thể hiện dữ liệu web.

# %% [markdown]
# ## 2. Cài đặt

# %% [markdown]
# ### 2.1. Import library

# %%
import requests
import re
from bs4 import BeautifulSoup
from bs4.element import Comment
import string

# %% [markdown]
# ### 2.2. HTML Parser

# %% [markdown]
# Bộ phân tích cú pháp HTML (HTML Parser): nhận HTML code và trích xuất thông tin liên quan như tiêu đề của trang, đoạn văn trong trang, tiêu đề trong trang, liên kết, văn bản in đậm, v.v.

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start tag:", tag)

    def handle_endtag(self, tag):
        print("End tag :", tag)

    def handle_data(self, data):
        print("Data  :", data)

parser = MyHTMLParser()
parser.feed('<html><head><title>Test</title></head>')
# Out:
# Start tag: html
# Start tag: head
# Start tag: title
# Data  : Test
# End tag : title
# End tag : head

# %% [markdown]
# #### Loại bỏ các HTML tag không cần thiết bằng cách thiết lập filter

# %%
def text_filter(element):
    if element.parent.name in ['style', 'title', 'script', 'head', '[document]', 'class', 'a', 'li']:
        return False
    elif isinstance(element, Comment):
        '''Opinion mining?'''
        return False
    elif re.match(r"[\s\r\n]+",str(element)): 
        '''space, return, endline'''
        return False
    return True

# %% [markdown]
# ### 2.3 Thu thập nội dung trang Web

# %% [markdown]
# #### Trong bài tập này ta thể hiện tài liệu (hay nội dung trang web) với cấu trúc đơn giản như sau:
# - Gọi $D$ là một tập tài liệu chứa *n* tài liệu: $D=\left\{d_1,d_2,...,d_n\right\}$.
# - Ta thể hiện tài liệu bằng một dictionary `data={}` với `data[word]=[[url_idx_1,url_idx_2,...],frequency]` với `url_index`$\in{\left[{1,n}\right]}$
#
# VD: `data['at']=[[1,2], 5]`
# Từ `at` xuất hiện trong đường dẫn có index `1` và `2` tổng số lần xuất hiện là 5.

# %% [markdown]
# #### Bước 1: liệt kê các từ xuất hiện trong trang web:

# %%
def wordList(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    text = soup.findAll(text=True)
    filtered_text = list(filter(text_filter, text)) # list của các chuỗi
    word_list = []

    # TODO:
    # Với mỗi chuỗi trong filtered_text:
    #   Thay thế các dấu câu thành khoảng trắng (gợi ý: danh sách các dấu câu: string.punctuation; thay thế: .replace(...))
    #   Tách chuỗi bởi khoảng trắng (.split(...))
    #   Thêm các từ vừa được tách ra vào word_list
    
    # remove all punctuation in filered_text
    for i in range(len(filtered_text)):
        for ele in filtered_text[i]:
            if ele in string.punctuation:
                filtered_text[i] = filtered_text[i].replace(ele, " ")

            # remove '\n' from filtered_text
            filtered_text[i] = filtered_text[i].replace('\n', " ")
            filtered_text[i] = filtered_text[i].replace('–', " ")
            filtered_text[i] = filtered_text[i].replace('\xa0', " ")
    
    # split by ' ' from filtered_text
    for i in filtered_text:
        word_list += i.split(' ')

    # remove all element '' in word_list
    word_list = list(filter(lambda a: a != '', word_list))
    return word_list
  
# Test
print(wordList('https://en.wikipedia.org/wiki/Web_mining'))
# for i in wordList('https://en.wikipedia.org/wiki/Web_mining'):
#     print(i)
# Out:
# ['Web', 'mining', 'From', 'Wikipedia', 'the', 'free', 'encyclopedia', 'This', 'article', 'includes', 'a', 'related', 'reading', 'or', 'but', 'its', 'sources', 'remain', 'unclear', 'because', 'it', 'lacks', 'October', '2020', 'This', 'article', 'may', 'require', 'The', 'specific', 'problem', 'is', 'The', 'article', 'needs', 'sufficient', 'inline', 'references', 'and', 'a', 'complete', 're', 'write', 'has', 'been', 'proposed', 'October', '2020', 'Web', 'mining', 'As', 'the', 'name', 'proposes', 'this', 'is', 'information', 'gathered', 'by', 'mining', 'the', 'web', 'It', 'makes', 'utilization', 'of', 'automated', 'apparatuses', 'to', 'reveal', 'and', 'extricate', 'data', 'from', 'servers', 'and', 'web2', 'reports', 'and', 'it', 'permits', 'organizations', 'to', 'get', 'to', 'both', 'organized', 'and', 'unstructured', 'information', 'from', 'browser', 'activities', 'server', 'logs', 'website', 'and', 'link', 'structure', 'page', 'content', 'and', 'different', 'sources', 'The', 'goal', 'of', 'Web', 'structure', 'mining', 'is', 'to', 'generate', 'structural', 'summary', 'about', 'the', 'Web', 'site', 'and', 'Web', 'page', 'Technically', 'Web', 'structure', 'mining', 'can', 'also', 'have', 'another', 'direction', 'discovering', 'the', 'structure', 'of', 'Web', 'document', 'itself', 'This', 'type', 'of', 'structure', 'mining', 'can', 'be', 'used', 'to', 'reveal', 'the', 'structure', 'schema', 'of', 'Web', 'pages', 'this', 'would', 'be', 'good', 'for', 'navigation', 'purpose', 'and', 'make', 'it', 'possible', 'to', 'compare', 'integrate', 'Web', 'page', 'schemes', 'This', 'type', 'of', 'structure', 'mining', 'will', 'facilitate', 'introducing', 'database', 'techniques', 'for', 'accessing', 'information', 'in', 'Web', 'pages', 'by', 'providing', 'a', 'reference', 'schema', 'Contents', '1', 'Web', 'mining', 'types', '2', 'Web', 'usage', 'mining', '2', '1', 'Pros', '2', '2', 'Cons', '3', 'Web', 'structure', 'mining', '4', 'Web', 'content', 'mining', '4', '1', 'Web', 'content', 'mining', 'in', 'foreign', 'languages', '4', '1', '1', 'Chinese', '5', 'See', 'also', '6', 'References', '6', '1', 'Books', '6', '2', 'Bibliographic', 'references', 'Web', 'mining', 'types', 'Web', 'mining', 'can', 'be', 'divided', 'into', 'three', 'different', 'types', 'Web', 'usage', 'mining', 'Web', 'content', 'mining', 'Web', 'structure', 'mining', 'The', 'general', 'relationship', 'between', 'the', 'categories', 'of', 'Web', 'mining', 'and', 'objectives', 'of', 'data', 'mining', 'Comparison', 'Web', 'content', 'mining', 'Web', 'structure', 'mining', 'Web', 'usage', 'mining', 'IR', 'view', 'DB', 'view', 'View', 'of', 'data', 'Main', 'data', 'Representation', 'Method', 'Application', 'categories', 'Web', 'usage', 'mining', 'Web', 'usage', 'mining', 'is', 'the', 'application', 'of', 'Usage', 'data', 'captures', 'the', 'identity', 'or', 'origin', 'of', 'Web', 'users', 'along', 'with', 'their', 'browsing', 'behavior', 'at', 'a', 'Web', 'site', 'Web', 'usage', 'mining', 'itself', 'can', 'be', 'classified', 'further', 'depending', 'on', 'the', 'kind', 'of', 'usage', 'data', 'considered', 'Web', 'server', 'data', 'Application', 'server', 'data', 'Application', 'level', 'data', 'Studies', 'related', 'to', 'work', 'Pros', 'Web', 'usage', 'mining', 'essentially', 'has', 'many', 'advantages', 'which', 'makes', 'this', 'technology', 'attractive', 'to', 'corporations', 'including', 'government', 'agencies', 'This', 'technology', 'has', 'enabled', 'which', 'eventually', 'results', 'in', 'higher', 'trade', 'volumes', 'Government', 'agencies', 'are', 'using', 'this', 'technology', 'to', 'classify', 'threats', 'and', 'The', 'predicting', 'capability', 'of', 'mining', 'applications', 'can', 'benefit', 'society', 'by', 'identifying', 'criminal', 'activities', 'Companies', 'can', 'establish', 'better', 'More', 'benefits', 'of', 'web', 'usage', 'mining', 'particularly', 'in', 'the', 'area', 'of', 'are', 'outlined', 'in', 'specific', 'frameworks', 'such', 'as', 'the', 'Cons', 'Web',  ...

# %% [markdown]
# #### Bước 2: Tính tần suất xuất hiện của từ trong 1 trang web, lưu trữ dữ liệu vào data:

# %%
def read_url(url, url_idx, data):
    word_list = wordList(url)
    # TODO
    # Với mỗi từ w trong word_list:
    #   Nếu w chưa có trong data thì khởi tạo data[w] = [[url_idx], 1]
    #   Ngược lại thì thêm url_idx vào data[w][0] (nếu chưa có) và tăng data[w][1] lên 1 đơn vị
    
    for w in word_list:
        if w in data:
            data[w][1] += 1
            if not url_idx in data[w][0]:
                data[w][0].append(url_idx)
        else:
            data[w] = [[url_idx], 1]

# Test
test_data = {}
read_url('https://en.wikipedia.org/wiki/Web_mining', 1, test_data)
test_data
# Out:
# {'Web': [[1], 47],
#  'mining': [[1], 43],
#  'From': [[1], 1],
#  'Wikipedia': [[1], 1],
#  'the': [[1], 38],
#  'free': [[1], 1],
#  'encyclopedia': [[1], 1],
#  'This': [[1], 8],
#  'article': [[1], 3],
#  'includes': [[1], 1],
#  'a': [[1], 9],
#  'related': [[1], 2],
#  'reading': [[1], 1],
#  'or': [[1], 6],
#  'but': [[1], 4],
#  'its': [[1], 1],
#  'sources': [[1], 2],
#  'remain': [[1], 1],
#  'unclear': [[1], 1],
#  'because': [[1], 1],
#  'it': [[1], 5],
#  'lacks': [[1], 1],
#  'October': [[1], 3],
#  '2020': [[1], 3],
#  'may': [[1], 1],
#  'require': [[1], 1],
#  'The': [[1], 10],
#  'specific': [[1], 4],
#  'problem': [[1], 1],
#  'is': [[1], 16],
#  'needs': [[1], 3],
#  'sufficient': [[1], 1],
#  'inline': [[1], 1],
#  'references': [[1], 3],
#  'and': [[1], 25],
#  'complete': [[1], 1],
#  're': [[1], 1],
#  'write': [[1], 1],
#  'has': [[1], 4],
#  'been': [[1], 1],
#  'proposed': [[1], 1],
#  'As': [[1], 2],
#  'name': [[1], 1],
#  'proposes': [[1], 1],
#  'this': [[1], 7],
#  'information': [[1], 6],
#  'gathered': [[1], 1],
#  'by': [[1], 5],
#  'web': [[1], 3],
#  'It': [[1], 1],
#  'makes': [[1], 2],
#  'utilization': [[1], 1],
#  'of': [[1], 32],
#  'automated': [[1], 1],
#  'apparatuses': [[1], 1],
#  'to': [[1], 20],
#  'reveal': [[1], 2],
#  'extricate': [[1], 1],
#  'data': [[1], 19],
#  'from': [[1], 8],
#  'servers': [[1], 1],
#  'web2': [[1], 1],
#  'reports': [[1], 1],
#  'permits': [[1], 1],
#  'organizations': [[1], 1],
#  'get': [[1], 1],
#  'both': [[1], 1],
#  'organized': [[1], 1],
#  'unstructured': [[1], 1],
#  'browser': [[1], 1],
#  'activities': [[1], 2],
#  'server': [[1], 3],
#  'logs': [[1], 1],
#  'website': [[1], 2],
#  'link': [[1], 1],
#  'structure': [[1], 14],
#  'page': [[1], 4],
#  'content': [[1], 10],
#  'different': [[1], 4],
#  'goal': [[1], 1],
#  'generate': [[1], 1],
#  'structural': [[1], 2],
#  'summary': [[1], 1],
#  'about': [[1], 1],
#  'site': [[1], 3],
#  'Technically': [[1], 1],
#  'can': [[1], 9],
#  'also': [[1], 3],
#  'have': [[1], 2],
#  'another': [[1], 1],
#  'direction': [[1], 1],
#  'discovering': [[1], 1],
#  'document': [[1], 2],
#  'itself': [[1], 3],
#  'type': [[1], 2],
#  'be': [[1], 5],
#  'used': [[1], 3],
#  'schema': [[1], 2],
#  'pages': [[1], 2],
#  'would': [[1], 1],
#  'good': [[1], 1],
#  'for': [[1], 7],
#  'navigation': [[1], 1],
#  'purpose': [[1], 2],
#  'make': [[1], 2],
#  'possible': [[1], 1],
#  'compare': [[1], 1],
#  'integrate': [[1], 1],
#  'schemes': [[1], 1],
#  'will': [[1], 2],
#  'facilitate': [[1], 1],
#  'introducing': [[1], 1],
#  'database': [[1], 2],
#  'techniques': [[1], 4],
#  'accessing': [[1], 1],
#  'in': [[1], 11],
#  'providing': [[1], 1],
#  'reference': [[1], 1],
#  'Contents': [[1], 1],
#  '1': [[1], 6],
#  'types': [[1], 3],
#  '2': [[1], 6],
#  'usage': [[1], 10],
#  'Pros': [[1], 2],
#  'Cons': [[1], 2],
#  '3': [[1], 1],
#  '4': [[1], 4],
#  'foreign': [[1], 2],
#  'languages': [[1], 2],
#  'Chinese': [[1], 2],
#  '5': [[1], 1],
#  'See': [[1], 2],
#  '6': [[1], 4],
#  'References': [[1], 2],
#  'Books': [[1], 2],
#  'Bibliographic': [[1], 2],
#  'divided': [[1], 1],
#  'into': [[1], 2],
#  'three': [[1], 1],
#  'general': [[1], 2],
#  'relationship': [[1], 1],
#  'between': [[1], 1],
#  'categories': [[1], 3],
#  'objectives': [[1], 1],
#  'Comparison': [[1], 1],
#  'IR': [[1], 1],
#  'view': [[1], 3],
#  'DB': [[1], 1],
#  'View': [[1], 1],
#  'Main': [[1], 1],
#  'Representation': [[1], 1],
#  'Method': [[1], 1],
#  'Application': [[1], 3],
#  'application': [[1], 1],
#  'Usage': [[1], 1],
#  'captures': [[1], 1],
#  'identity': [[1], 1],
#  'origin': [[1], 1],
#  'users': [[1], 2],
#  'along': [[1], 1],
#  'with': [[1], 1],
#  'their': [[1], 2],
#  'browsing': [[1], 1],
#  'behavior': [[1], 1],
#  'at': [[1], 1],
#  'classified': [[1], 1],
#  'further': [[1], 1],
#  'depending': [[1], 1],
#  'on': [[1], 2],
#  'kind': [[1], 1],
#  'considered': [[1], 3],
#  'level': [[1], 2],
#  'Studies': [[1], 1],
#  'work': [[1], 1],
#  'essentially': [[1], 2],
#  'many': [[1], 1],
#  'advantages': [[1], 1],
#  'which': [[1], 3],
#  'technology': [[1], 4],
#  'attractive': [[1], 1],
#  'corporations': [[1], 1],
#  'including': [[1], 1],
#  'government': [[1], 1],
#  'agencies': [[1], 2],
#  'enabled': [[1], 1],
#  'eventually': [[1], 1],
#  'results': [[1], 1],
#  'higher': [[1], 2],
#  'trade': [[1], 2],
#  'volumes': [[1], 1],
#  'Government': [[1], 1],
#  'are': [[1], 6],
#  'using': [[1], 1],
#  'classify': [[1], 1],
#  'threats': [[1], 1],
#  'predicting': [[1], 1],
#  'capability': [[1], 1],
#  'applications': [[1], 1],
#  'benefit': [[1], 1],
#  'society': [[1], 1],
#  'identifying': [[1], 1],
#  'criminal': [[1], 1],
#  'Companies': [[1], 1],
#  'establish': [[1], 1],
#  'better': [[1], 1],
#  'More': [[1], 2],
#  'benefits': [[1], 1],
#  'particularly': [[1], 1],
#  'area': [[1], 1],
#  'outlined': [[1], 1],
#  'frameworks': [[1], 1],
#  'such': [[1], 2],
#  'as': [[1], 5],
#  'does': [[1], 1],
#  'not': [[1], 2],
#  'create': [[1], 1],
#  'issues': [[1], 1],
#  'when': [[1], 2],
#  'Privacy': [[1], 2],
#  'lost': [[1], 1],
#  'concerning': [[1], 1],
#  'an': [[1], 3],
#  'individual': [[1], 2],
#  'obtained': [[1], 2],
#  'disseminated': [[1], 1],
#  'especially': [[1], 1],
#  'if': [[1], 2],
#  'occurs': [[1], 1],
#  'without': [[1], 1],
#  's': [[1], 3],
#  'knowledge': [[1], 3],
#  'consent': [[1], 1],
#  'then': [[1], 2],
#  'Another': [[1], 1],
#  'important': [[1], 1],
#  'concern': [[1], 1],
#  'that': [[1], 2],
#  'companies': [[1], 3],
#  'collecting': [[1], 1],
#  'might': [[1], 3],
#  'use': [[1], 3],
#  'totally': [[1], 1],
#  'purposes': [[1], 1],
#  'violates': [[1], 1],
#  'user': [[1], 1],
#  'interests': [[1], 1],
#  'growing': [[1], 1],
#  'trend': [[1], 2],
#  'selling': [[1], 1],
#  'personal': [[1], 2],
#  'commodity': [[1], 1],
#  'encourages': [[1], 1],
#  'owners': [[1], 1],
#  'increased': [[1], 1],
#  'amount': [[1], 1],
#  'being': [[1], 2],
#  'captured': [[1], 1],
#  'traded': [[1], 1],
#  'increasing': [[1], 1],
#  'likeliness': [[1], 1],
#  'one': [[1], 2],
#  'privacy': [[1], 1],
#  'invaded': [[1], 1],
#  'buy': [[1], 1],
#  'obliged': [[1], 1],
#  'anonymous': [[1], 1],
#  'these': [[1], 1],
#  'authors': [[1], 1],
#  'any': [[1], 2],
#  'release': [[1], 3],
#  'patterns': [[1], 2],
#  'They': [[1], 1],
#  'legally': [[1], 1],
#  'responsible': [[1], 1],
#  'contents': [[1], 1],
#  'inaccuracies': [[1], 1],
#  'result': [[1], 2],
#  'serious': [[1], 1],
#  'lawsuits': [[1], 1],
#  'there': [[1], 1],
#  'no': [[1], 1],
#  'law': [[1], 1],
#  'preventing': [[1], 1],
#  'them': [[1], 1],
#  'trading': [[1], 1],
#  'Some': [[1], 1],
#  'algorithms': [[1], 1],
#  'controversial': [[1], 1],
#  'attributes': [[1], 1],
#  'like': [[1], 1],
#  'sex': [[1], 1],
#  'race': [[1], 1],
#  'religion': [[1], 1],
#  'sexual': [[1], 1],
#  'orientation': [[1], 1],
#  'categorize': [[1], 2],
#  'individuals': [[1], 1],
#  'These': [[1], 2],
#  'practices': [[1], 1],
#  'against': [[1], 1],
#  'anti': [[1], 1],
#  'discrimination': [[1], 1],
#  'legislation': [[1], 1],
#  'section': [[1], 2],
#  'expansion': [[1], 1],
#  'You': [[1], 1],
#  'help': [[1], 1],
#  'June': [[1], 1],
#  '2015': [[1], 1],
#  'appropriate': [[1], 1],
#  'uses': [[1], 1],
#  'terminology': [[1], 1],
#  'An': [[1], 1],
#  'example': [[1], 2],
#  'extraction': [[1], 2],
#  'integration': [[1], 1],
#  'useful': [[1], 3],
#  'heterogeneity': [[1], 1],
#  'others': [[1], 1],
#  'provide': [[1], 3],
#  'some': [[1], 1],
#  'comfort': [[1], 1],
#  'they': [[1], 1],
#  'do': [[1], 1],
#  'generally': [[1], 1],
#  'nor': [[1], 1],
#  'filter': [[1], 1],
#  'interpret': [[1], 1],
#  'documents': [[1], 3],
#  'factors': [[1], 1],
#  'prompted': [[1], 1],
#  'researchers': [[1], 1],
#  'develop': [[1], 1],
#  'more': [[1], 1],
#  'intelligent': [[1], 2],
#  'tools': [[1], 2],
#  'well': [[1], 1],
#  'extend': [[1], 1],
#  'organization': [[1], 1],
#  'differentiated': [[1], 1],
#  'two': [[1], 1],
#  'points': [[1], 1],
#  'There': [[1], 1],
#  'several': [[1], 1],
#  'ways': [[1], 1],
#  'represent': [[1], 1],
#  'By': [[1], 1],
#  'multi': [[1], 1],
#  'scanning': [[1], 1],
#  'we': [[1], 1],
#  'implement': [[1], 1],
#  'feature': [[1], 3],
#  'selection': [[1], 1],
#  'Under': [[1], 1],
#  'condition': [[1], 1],
#  'category': [[1], 1],
#  'rarely': [[1], 1],
#  'affected': [[1], 1],
#  'subset': [[1], 1],
#  'needed': [[1], 1],
#  'algorithm': [[1], 1],
#  'construct': [[1], 1],
#  'evaluating': [[1], 1],
#  'function': [[1], 1],
#  'evaluate': [[1], 1],
#  'features': [[1], 1],
#  'set': [[1], 1],
#  'complement': [[1], 1],
#  'retrieval': [[1], 1],
#  'aggregation': [[1], 1],
#  'works': [[1], 1],
#  'academic': [[1], 1],
#  'publications': [[1], 1],
#  'identify': [[1], 1],
#  'code': [[1], 2],
#  'standard': [[1], 1],
#  'HTML': [[1], 1],
#  'transform': [[1], 1],
#  'inner': [[1], 1],
#  'other': [[1], 1],
#  'find': [[1], 1],
#  'Weichbroth': [[1], 1],
#  'et': [[1], 1],
#  'al': [[1], 1],
#  'Ngu': [[1], 1],
#  'Anne': [[1], 1],
#  'Kitsuregawa': [[1], 1],
#  'Masaru': [[1], 1],
#  'Chung': [[1], 1],
#  'Jen': [[1], 1],
#  'Yao': [[1], 1],
#  'Neuhold': [[1], 1],
#  'Erich': [[1], 1],
#  'Sheng': [[1], 1],
#  'Quan': [[1], 1],
#  '2005': [[1], 3],
#  'Information': [[1], 1],
#  'Systems': [[1], 1],
#  'Engineering': [[1], 1],
#  'WISE': [[1], 1],
#  'Berlin': [[1], 2],
#  'Springer': [[1], 2],
#  'pp': [[1], 3],
#  '9783540300175': [[1], 1],
#  'Bauknecht': [[1], 1],
#  'Kurt': [[1], 1],
#  'Madria': [[1], 1],
#  'Sanjay': [[1], 1],
#  'Pernul': [[1], 1],
#  'Gunther': [[1], 1],
#  '2000': [[1], 4],
#  'Electronic': [[1], 1],
#  'Commerce': [[1], 1],
#  'Technologies': [[1], 1],
#  'First': [[1], 1],
#  'International': [[1], 1],
#  'Conference': [[1], 1],
#  'EC': [[1], 1],
#  'London': [[1], 1],
#  'UK': [[1], 1],
#  'September': [[1], 1],
#  'Proceedings': [[1], 1],
#  '978': [[1], 2],
#  '3540679813': [[1], 1],
#  'Scime': [[1], 1],
#  'Anthony': [[1], 1],
#  'Mining': [[1], 4],
#  'Applications': [[1], 1],
#  'Techniques': [[1], 1],
#  'Hershey': [[1], 1],
#  'PA': [[1], 1],
#  'Idea': [[1], 1],
#  'Group': [[1], 1],
#  'Publishing': [[1], 1],
#  '1591404149': [[1], 1],
#  'b': [[1], 1],
#  'c': [[1], 1],
#  'Lita': [[1], 1],
#  'van': [[1], 1],
#  'Wel': [[1], 1],
#  'Lambèr': [[1], 1],
#  'Royakkers': [[1], 1],
#  '2004': [[1], 1],
#  'PDF': [[1], 2],
#  'Ethical': [[1], 1],
#  'Issues': [[1], 2],
#  'Data': [[1], 2],
#  'Kirsten': [[1], 1],
#  'Maelstrom': [[1], 1],
#  'John': [[1], 1],
#  'F': [[1], 1],
#  'Rodrick': [[1], 1],
#  'Vladimir': [[1], 1],
#  'Estivill': [[1], 1],
#  'Castro': [[1], 1],
#  'Denise': [[1], 1],
#  'de': [[1], 1],
#  'Vries': [[1], 1],
#  '2007': [[1], 1],
#  'Legal': [[1], 1],
#  'Technical': [[1], 1],
#  'Preservation': [[1], 1],
#  'Wang': [[1], 1],
#  'Yan': [[1], 1],
#  'Kosala': [[1], 1],
#  'Raymond': [[1], 1],
#  'Hendrik': [[1], 1],
#  'Blockeel': [[1], 1],
#  'July': [[1], 1],
#  'Research': [[1], 1],
#  'A': [[1], 2],
#  'Survey': [[1], 1],
#  'SIGKDD': [[1], 1],
#  'Explorations': [[1], 1],
#  'Speirs': [[1], 1],
#  'Martha': [[1], 1],
#  '2013': [[1], 1],
#  'Cite': [[1], 1],
#  'journal': [[1], 2],
#  'requires': [[1], 1],
#  'Dhakal': [[1], 1],
#  'Kerry': [[1], 1],
#  '15': [[1], 1],
#  'April': [[1], 1],
#  '2019': [[1], 1],
#  'Journal': [[1], 1],
#  'Medical': [[1], 1],
#  'Library': [[1], 1],
#  'Association': [[1], 1],
#  '107': [[1], 1],
#  'Retrieved': [[1], 1],
#  'Hidden': [[1], 1],
#  'Navigation': [[1], 2],
#  'menu': [[1], 1],
#  'Personal': [[1], 1],
#  'Namespaces': [[1], 1],
#  'Variants': [[1], 1],
#  'Views': [[1], 1],
#  'Search': [[1], 1],
#  'Contribute': [[1], 1],
#  'Tools': [[1], 1],
#  'Print': [[1], 1],
#  'export': [[1], 1],
#  'Languages': [[1], 1]}

# %% [markdown]
# #### Bước 3: Chạy chương trình lưu kết quả vào file output.txt

# %%
data = {}
read_url('https://en.wikipedia.org/wiki/Web_mining', 1, data)
read_url('https://en.wikipedia.org/wiki/Data_mining', 2, data)

sorted_keys = sorted(data.keys())

with open("output.txt", "w", encoding="utf-8") as f:
    output_line = "Word".ljust(20) + "Frequency".ljust(15) + "URL_idx".ljust(15) + "\n"
    f.writelines(output_line)
    f.writelines('---------------------------------------------------------------------\n\n')
    for key in sorted_keys:
        output_string = str(key).ljust(20) + str(data[key][1]).ljust(15) + str(data[key][0]).ljust(15) + "\n"
        f.writelines(output_string)

# %%
# TODO
# Keyword tìm kiếm: python pickle
# Dùng pickle để lưu dictionary data xuống đĩa. Sau đó đọc lên và in ra 10 giá trị đầu tiên của nó.

# 1. Lưu data
import pickle
filename = 'pickle.txt'
outfile = open(filename,'wb')
pickle.dump(data, outfile)

# 2. Đọc lên và in ra
with open(filename, "rb") as f:
    db = pickle.load(f)
    k = 0
    for i in db:
        if k < 10:
            print(str(i).ljust(20) + " : " + str(db[i]))
        else:
            break
        k+=1
# Out:
# Web                  : [[1, 2], 48]
# mining               : [[1, 2], 95]
# From                 : [[1, 2], 3]
# Wikipedia            : [[1, 2], 2]
# the                  : [[1, 2], 125]
# free                 : [[1, 2], 3]
# encyclopedia         : [[1, 2], 2]
# This                 : [[1, 2], 12]
# article              : [[1, 2], 5]
# includes             : [[1], 1]
